# %% [markdown]
# # MACE tutorial
#
# MACE is an open source toolkit for the automated screening and discovery of octahedral and square-planar mononuclear complexes. The software generates all possible configurations for square-planar and octahedral metal complexes and atomic 3D coordinates suitable for quantum-chemical computations. It supports ligands of high complexity and can be used for the development of a massive computational pipelines aimed at solving problems of homogenious catalysis.
#
# This document showcases the main features of MACE and provides example recipes of how to carry out particular tasks using the available functionality.

# %% [markdown]
# # Complex object
#
# In MACE, the central entity is a `Complex` object. It can be generated from SMILES of the metal complex, from SMILES of ligands and a central atom, and from a MACE-generated `.xyz` file.
#
# ### Direct initialization
#
# In MACE, the central entity is a `Complex` object. To initialize it, one requires SMILES of the metal complex and geometry of the central atom. SMILES must satisfy the following conditions:
#
# 1. Donor atoms of ligands have non-zero atomic map number: 1-6 for octahedral (`geom = 'OH'`) and 1-4 for square-planar (`geom = 'SP'`) geometries. This enumeration is used to describe a spatial arrangement of ligands around a central atom:
#
# <img src="pics/geoms_scheme.png" width="30%">
#
# 2. Other atoms have unspecified atomic map number and isotopic number, except where otherwise noted (see the "Adding substituents" subsection);
#
# 3. Bonds between central atom and ligands are dative;
#
# 4. The complex contains one central atom only.

# %%
import mace

X = mace.Complex(smiles = '[NH3:1]->[Pt+2](<-[NH3:2])(<-[Cl-:3])(<-[Cl-:4])', geom = 'SP')
X.mol

# %%
X = mace.Complex(smiles = '[Cl-:1]->[Ru+2](<-[Cl-:2])(<-[NH2:3]CC1)(<-[NH2:4]1)(<-[NH2:5]CC1)(<-[NH2:6]1)', geom = 'OH')
X.mol

# %% [markdown]
# The third argument `maxResonanceStructures` can be ignored in most cases. It is needed for complexes containing symmetrical multidentate ligands with an asymmetric arrangement of multiple bonds in the resonance structure used in the SMILES string. It will be discussed in more details in the "Issue of resonance structures" section.

# %% [markdown]
# The other way to generate the `Complex` object is to generate it from the ligands:

# %%
ligands = ['[NH2:1]CC[NH2:2]', '[NH2:3]CC[NH2:4]', '[Cl-:5]', '[Cl-:6]']
X = mace.ComplexFromLigands(ligands = ligands, CA = '[Ru+2]', geom = 'OH')
X.mol

# %% [markdown]
# Finally, `Complex` can be read from MACE-generated `xyz`-file. However, that is possible if only `Complex` has at least one conformer. Thus, it will be discussed in the "Embedding" section.

# %% [markdown]
# ### SMILES notations
#
# MACE uses [RDKit](https://www.rdkit.org/docs/RDKit_Book.html#smiles-support-and-extensions) and [ChemAxon](https://docs.chemaxon.com/display/docs/smiles.md) SMILES specifications which support dative bonds (unlike much more popular [Daylight SMILES](https://www.daylight.com/dayhtml/doc/theory/theory.smiles.html) and [OpenSMILES](http://opensmiles.org/opensmiles.html)).
#
# RDKit SMILES is most convenient with manual generation for relatively small metal complexes, though this requires some experience with the SMILES notation. On the contrary, ChemAxon SMILES can be generated for any metal complex using the [ChemAxon Marvin](https://chemaxon.com/marvin) chemical editor. For the purpose, one need to draw the complex, arrange the atomic map numbers, and copy the structure as ChemAxon SMILES:
#
# <img src="pics/marvin_get_smiles.png">

# %% [markdown]
# ## Embedding
#
# If atomic map numbers of donor atoms are correct (no repeats, lies in range \[1,6\]/\[1,4\] for OH/SP geometry, etc.), than one can generate 3D atomic coordinates:

# %%
import py3Dmol

def view_complex(X, confId = 0):
    '''Shows molecule corresponding to the SMILES'''
    view = py3Dmol.view()
    view.addModel(X.ToXYZBlock(confId = confId), 'xyz')
    view.setStyle({'stick': {'radius': 0.15}, 'sphere': {'scale': 0.3}})
    view.setBackgroundColor('white')
    view.zoomTo()
    
    return view

ligands = ['[NH2:1]CC[NH2:2]', '[NH2:3]CC[NH2:4]', '[Cl-:5]', '[Cl-:6]']
X = mace.ComplexFromLigands(ligands = ligands, CA = '[Ru+2]', geom = 'OH')
X.AddConformer()
view_complex(X)
# Out:
# <div id="3dmolviewer_16763817774808137"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16763817774808137" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_16763817774808137 = null;
# var warn = document.getElementById("3dmolwarning_16763817774808137");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16763817774808137 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16763817774808137"),{backgroundColor:"white"});
# viewer_16763817774808137.zoomTo();
# 	viewer_16763817774808137.addModel("27\n{\"conf\": 0, \"E\": 69.45, \"rms\": -1.0, \"geom\": \"OH\", \"total_charge\": 0, \"CA_charge\": 2, \"smiles\": \"[1NH2]1->[Ru+2:10]2(<-[5Cl-:8])(<-[6Cl-:9])(<-[2NH2:3][CH2:2][CH2:1]1)<-[3NH2:4][CH2:5][CH2:6][4NH2:7]->2\", \"smiles3D\": \"[1N]1([H:11])([H:12])->[Ru+2:10]2(<-[5Cl-:8])(<-[6Cl-:9])(<-[2N:3]([H:17])([H:18])[C:2]([H:15])([H:16])[C:1]1([H:13])[H:14])<-[3N:4]([H:19])([H:20])[C:5]([H:21])([H:22])[C:6]([H:23])([H:24])[4N:7]->2([H:25])[H:26]\", \"smiles3Dx\": \"[1N]1([H:11])([H:12])->[Ru+2:10]2(<-[5Cl-:8])(<-[6Cl-:9])(<-[2N:3]([H:17])([H:18])[C:2]([H:15])([H:16])[C:1]1([H:13])[H:14])<-[3N:4]([H:19])([H:20])[C:5]([H:21])([H:22])[C:6]([H:23])([H:24])[4N:7]->2([H:25])[H:26]\", \"dummies\": []}\nN      0.1633     1.3593    -1.4342\nC     -1.1192     1.9992    -1.6410\nC     -2.3519     0.9322    -1.2251\nN     -1.9669     0.1862    -0.0479\nN      0.1023     1.4313     1.3682\nC      1.4833     1.8269     1.5506\nC      2.4909     0.5284     1.1906\nN      1.9670    -0.1860     0.0479\nCl    -0.1265    -1.7724    -1.6942\nCl    -0.2024    -1.6832     1.7759\nRu     0.0000     0.0000     0.0000\nH      0.4296     0.9551    -2.2072\nH      0.7788     1.9846    -1.1910\nH     -1.2224     2.2864    -2.7124\nH     -1.1864     2.9098    -1.0046\nH     -2.5331     0.2278    -2.0681\nH     -3.2834     1.5054    -1.0134\nH     -2.3503    -0.6417    -0.0734\nH     -2.2487     0.6289     0.6984\nH     -0.3853     2.1494     1.0933\nH     -0.2320     1.1213     2.1582\nH      1.7181     2.6778     0.8725\nH      1.6436     2.1394     2.6078\nH      2.5398    -0.1573     2.0665\nH      3.5128     0.9052     0.9565\nH      2.1875    -1.0691     0.1139\nH      2.3239     0.1603    -0.7170\n","xyz");
# 	viewer_16763817774808137.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_16763817774808137.setBackgroundColor("white");
# 	viewer_16763817774808137.zoomTo();
# viewer_16763817774808137.render();
# });
# </script>

# %% [markdown]
# If the atomic map numbers are set incorrectly, one must first generate possible stereomers (see the "Stereomers generation" section):

# %%
ligands = ['[NH2:1]CC[NH2:1]', '[NH2:1]CC[NH2:1]', '[Cl-:1]', '[Cl-:1]']
X1 = mace.ComplexFromLigands(ligands = ligands, CA = '[Ru+2]', geom = 'OH')
try:
    X1.AddConformer()
except Exception as e:
    print(e)
# Out:
# Bad SMILES: isotopic labels are not unique
#
# The initial SMILES contains insufficient or erroneous info
# on the positions of the ligands around the central atom
# encoded with isotopic labels.
#
# To use 3D generation and other features, first generate
# possible stereomers

# %% [markdown]
# The main parameters of `Complex.AddConformers` method are number of conformers to generate `numConfs` and minimal RMSD between conformers when they are considered as identical `rmsThresh`:

# %%
ligands = ['C[P:2](C)CCC[N:3](C)CCC[P:4](C)C', '[C-:1]#[O+]', '[C-:5]#[O+]', '[C-:6]#[O+]']
X = mace.ComplexFromLigands(ligands = ligands, CA = '[Ru+2]', geom = 'OH')
X.AddConformers(numConfs = 10, rmsThresh = 2.0)
X.GetNumConformers()
# Out:
# 5

# %% [markdown]
# As one can see, number of generated conformers is less than `numConfs` value due to the filtering of similar conformations.

# %% [markdown]
# Analysis of molecular mechanical energies help to identify "good" and "bad" (potentially unsuitable for QM computations) geometries:

# %%
Es = [round(X.mol3Dx.GetConformer(idx).GetDoubleProp("E"), 1) for idx in range(X.GetNumConformers())]
Es
# Out:
# [191.7, 191.3, 191.3, 184.8, 191.3]

# %%
import numpy as np
# best conformation
view_complex(X, confId = int(np.argmin(Es)))
# Out:
# <div id="3dmolviewer_16763817821520255"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16763817821520255" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_16763817821520255 = null;
# var warn = document.getElementById("3dmolwarning_16763817821520255");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16763817821520255 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16763817821520255"),{backgroundColor:"white"});
# viewer_16763817821520255.zoomTo();
# 	viewer_16763817821520255.addModel("48\n{\"conf\": 3, \"E\": 184.85, \"rms\": -1.0, \"geom\": \"OH\", \"total_charge\": 2, \"CA_charge\": 2, \"smiles\": \"C[2P:1]1([CH3:2])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([CH3:7])([CH2:5][CH2:4][CH2:3]1)[CH2:8][CH2:9][CH2:10][4P:11]->2([CH3:12])[CH3:13]\", \"smiles3D\": \"C([2P:1]1([C:2]([H:24])([H:25])[H:26])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([C:7]([H:33])([H:34])[H:35])([C:5]([H:31])([H:32])[C:4]([H:29])([H:30])[C:3]1([H:27])[H:28])[C:8]([H:36])([H:37])[C:9]([H:38])([H:39])[C:10]([H:40])([H:41])[4P:11]->2([C:12]([H:42])([H:43])[H:44])[C:13]([H:45])([H:46])[H:47])([H:21])([H:22])[H:23]\", \"smiles3Dx\": \"C([2P:1]1([C:2]([H:24])([H:25])[H:26])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([C:7]([H:33])([H:34])[H:35])([C:5]([H:31])([H:32])[C:4]([H:29])([H:30])[C:3]1([H:27])[H:28])[C:8]([H:36])([H:37])[C:9]([H:38])([H:39])[C:10]([H:40])([H:41])[4P:11]->2([C:12]([H:42])([H:43])[H:44])[C:13]([H:45])([H:46])[H:47])([H:21])([H:22])[H:23]\", \"dummies\": []}\nC     -3.4631     0.3317    -0.4706\nP     -2.3383    -0.6632     0.5029\nC     -2.6696    -0.4083     2.2424\nC     -2.5656    -2.3715     0.1035\nC     -1.2450    -3.1273     0.3163\nC      0.1612    -3.1440    -0.4387\nN      0.2708    -1.9458    -1.3069\nC     -0.7761    -1.9919    -2.3415\nC      1.5821    -1.9253    -1.9431\nC      1.7341    -0.6293    -2.7661\nC      2.8006     0.2757    -2.2157\nP      2.4168     0.6856    -0.5197\nC      2.6023     2.4478    -0.2756\nC      3.5350    -0.1903     0.5746\nC      0.6756    -1.0690     1.7316\nO      1.0556    -1.6703     2.7056\nC     -0.2457     1.7647     1.1853\nO     -0.3841     2.7589     1.8531\nC     -0.6771     1.0714    -1.7353\nO     -1.0571     1.6727    -2.7094\nRu     0.0000     0.0000     0.0000\nH     -4.5090     0.1426    -0.1379\nH     -3.2207     1.4026    -0.3343\nH     -3.3617     0.0632    -1.5418\nH     -3.7162    -0.7004     2.4662\nH     -2.5225     0.6627     2.4939\nH     -1.9762    -1.0279     2.8451\nH     -3.3507    -2.8047     0.7613\nH     -2.8761    -2.4643    -0.9486\nH     -1.0166    -3.0256     1.3975\nH     -1.5625    -4.1924     0.2685\nH      0.9824    -3.1360     0.3084\nH      0.2364    -4.0643    -1.0639\nH     -1.5125    -1.2086    -2.1494\nH     -1.2773    -2.9864    -2.3185\nH     -0.3173    -1.8317    -3.3395\nH      2.3664    -1.9634    -1.1696\nH      1.6820    -2.8088    -2.6183\nH      0.8420    -0.0844    -3.0502\nH      2.1152    -0.9448    -3.7630\nH      2.8450     1.2076    -2.8215\nH      3.7845    -0.2416    -2.2587\nH      2.7901     2.6546     0.7975\nH      3.4575     2.8167    -0.8784\nH      1.6741     2.9652    -0.5951\nH      3.1931    -1.2399     0.6901\nH      4.5574    -0.1797     0.1442\nH      3.5462     0.3042     1.5625\n","xyz");
# 	viewer_16763817821520255.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_16763817821520255.setBackgroundColor("white");
# 	viewer_16763817821520255.zoomTo();
# viewer_16763817821520255.render();
# });
# </script>

# %%
# worst conformation
view_complex(X, confId = int(np.argmax(Es)))
# Out:
# <div id="3dmolviewer_1676381782168039"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1676381782168039" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_1676381782168039 = null;
# var warn = document.getElementById("3dmolwarning_1676381782168039");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1676381782168039 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1676381782168039"),{backgroundColor:"white"});
# viewer_1676381782168039.zoomTo();
# 	viewer_1676381782168039.addModel("48\n{\"conf\": 0, \"E\": 191.66, \"rms\": -1.0, \"geom\": \"OH\", \"total_charge\": 2, \"CA_charge\": 2, \"smiles\": \"C[2P:1]1([CH3:2])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([CH3:7])([CH2:5][CH2:4][CH2:3]1)[CH2:8][CH2:9][CH2:10][4P:11]->2([CH3:12])[CH3:13]\", \"smiles3D\": \"C([2P:1]1([C:2]([H:24])([H:25])[H:26])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([C:7]([H:33])([H:34])[H:35])([C:5]([H:31])([H:32])[C:4]([H:29])([H:30])[C:3]1([H:27])[H:28])[C:8]([H:36])([H:37])[C:9]([H:38])([H:39])[C:10]([H:40])([H:41])[4P:11]->2([C:12]([H:42])([H:43])[H:44])[C:13]([H:45])([H:46])[H:47])([H:21])([H:22])[H:23]\", \"smiles3Dx\": \"C([2P:1]1([C:2]([H:24])([H:25])[H:26])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([C:7]([H:33])([H:34])[H:35])([C:5]([H:31])([H:32])[C:4]([H:29])([H:30])[C:3]1([H:27])[H:28])[C:8]([H:36])([H:37])[C:9]([H:38])([H:39])[C:10]([H:40])([H:41])[4P:11]->2([C:12]([H:42])([H:43])[H:44])[C:13]([H:45])([H:46])[H:47])([H:21])([H:22])[H:23]\", \"dummies\": []}\nC     -1.6770     0.8781    -3.1611\nP     -1.6396    -0.5267    -2.0506\nC     -1.0503    -1.9644    -2.9294\nC     -3.2816    -0.8397    -1.4332\nC     -3.3105    -0.6168    -0.0255\nC     -2.5035    -1.7108     0.7069\nN     -1.4613    -1.1086     1.4536\nC     -2.0443    -0.1253     2.4215\nC     -0.7193    -2.1538     2.1980\nC      0.2221    -1.4610     3.2979\nC      1.6482    -0.9382     2.9960\nP      1.5447     0.4961     1.9315\nC      3.1723     0.8930     1.3064\nC      0.9052     1.8923     2.8674\nC     -1.0412     1.8433     0.3591\nO     -1.6261     2.8788     0.5608\nC      1.3350     1.0128    -1.3277\nO      2.0879     1.5839    -2.0765\nC      1.0395    -1.8403    -0.3585\nO      1.6243    -2.8756    -0.5602\nRu     0.0000     0.0000     0.0000\nH     -0.6397     1.1636    -3.4313\nH     -2.1747     1.7282    -2.6625\nH     -2.2366     0.6089    -4.0783\nH     -1.8393    -2.3279    -3.6114\nH     -0.1433    -1.6932    -3.5207\nH     -0.7924    -2.7645    -2.2008\nH     -4.0037    -0.1530    -1.9330\nH     -3.5644    -1.8972    -1.6481\nH     -2.9885     0.4297     0.0508\nH     -4.3689    -0.6619     0.3177\nH     -2.0677    -2.4127    -0.0393\nH     -3.1783    -2.2723     1.3959\nH     -2.3021    -0.6482     3.3733\nH     -2.9351     0.3106     1.9983\nH     -1.3210     0.6553     2.6228\nH     -0.1035    -2.7293     1.5018\nH     -1.4431    -2.8345     2.7039\nH     -0.2696    -0.7601     3.9944\nH      0.4213    -2.3025     3.9964\nH      2.2345    -1.7337     2.4893\nH      2.1493    -0.6578     3.9479\nH      3.8997     0.8941     2.1435\nH      3.4752     0.1338     0.5532\nH      3.1521     1.8949     0.8334\nH      0.2638     1.5236     3.6860\nH      1.7505     2.4710     3.2922\nH      0.3184     2.5361     2.2064\n","xyz");
# 	viewer_1676381782168039.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_1676381782168039.setBackgroundColor("white");
# 	viewer_1676381782168039.zoomTo();
# viewer_1676381782168039.render();
# });
# </script>

# %% [markdown]
# Generated conformations can be saved to the `xyz` files, which can be used futher in various computational pipelines:

# %%
path = 'Ru_PNP_CO3.xyz'
X.ToXYZ(path)
with open(path, 'r') as inpf:
    for _ in range(10):
        print(inpf.readline(), end = '')
    print('...')
# Out:
# 48
# {"conf": 0, "E": 191.66, "rms": -1.0, "geom": "OH", "total_charge": 2, "CA_charge": 2, "smiles": "C[2P:1]1([CH3:2])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([CH3:7])([CH2:5][CH2:4][CH2:3]1)[CH2:8][CH2:9][CH2:10][4P:11]->2([CH3:12])[CH3:13]", "smiles3D": "C([2P:1]1([C:2]([H:24])([H:25])[H:26])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([C:7]([H:33])([H:34])[H:35])([C:5]([H:31])([H:32])[C:4]([H:29])([H:30])[C:3]1([H:27])[H:28])[C:8]([H:36])([H:37])[C:9]([H:38])([H:39])[C:10]([H:40])([H:41])[4P:11]->2([C:12]([H:42])([H:43])[H:44])[C:13]([H:45])([H:46])[H:47])([H:21])([H:22])[H:23]", "smiles3Dx": "C([2P:1]1([C:2]([H:24])([H:25])[H:26])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([C:7]([H:33])([H:34])[H:35])([C:5]([H:31])([H:32])[C:4]([H:29])([H:30])[C:3]1([H:27])[H:28])[C:8]([H:36])([H:37])[C:9]([H:38])([H:39])[C:10]([H:40])([H:41])[4P:11]->2([C:12]([H:42])([H:43])[H:44])[C:13]([H:45])([H:46])[H:47])([H:21])([H:22])[H:23]", "dummies": []}
# C     -1.6770     0.8781    -3.1611
# P     -1.6396    -0.5267    -2.0506
# C     -1.0503    -1.9644    -2.9294
# C     -3.2816    -0.8397    -1.4332
# C     -3.3105    -0.6168    -0.0255
# C     -2.5035    -1.7108     0.7069
# N     -1.4613    -1.1086     1.4536
# C     -2.0443    -0.1253     2.4215
# ...

# %% [markdown]
# The second line of the file contains JSON with information required to regenerate `Complex` object:

# %%
X = mace.ComplexFromXYZFile(path)
X.GetNumConformers()
view_complex(X, confId = int(np.argmin(Es)))
# Out:
# <div id="3dmolviewer_16763817822501125"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16763817822501125" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_16763817822501125 = null;
# var warn = document.getElementById("3dmolwarning_16763817822501125");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16763817822501125 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16763817822501125"),{backgroundColor:"white"});
# viewer_16763817822501125.zoomTo();
# 	viewer_16763817822501125.addModel("48\n{\"conf\": 3, \"E\": 184.85, \"rms\": -1.0, \"geom\": \"OH\", \"total_charge\": 2, \"CA_charge\": 2, \"smiles\": \"C[2P:1]1([CH3:2])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([CH3:7])([CH2:5][CH2:4][CH2:3]1)[CH2:8][CH2:9][CH2:10][4P:11]->2([CH3:12])[CH3:13]\", \"smiles3D\": \"C([2P:1]1([C:2]([H:24])([H:25])[H:26])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([C:7]([H:33])([H:34])[H:35])([C:5]([H:31])([H:32])[C:4]([H:29])([H:30])[C:3]1([H:27])[H:28])[C:8]([H:36])([H:37])[C:9]([H:38])([H:39])[C:10]([H:40])([H:41])[4P:11]->2([C:12]([H:42])([H:43])[H:44])[C:13]([H:45])([H:46])[H:47])([H:21])([H:22])[H:23]\", \"smiles3Dx\": \"C([2P:1]1([C:2]([H:24])([H:25])[H:26])->[Ru+2:20]2(<-[1C-:14]#[O+:15])(<-[5C-:16]#[O+:17])(<-[6C-:18]#[O+:19])<-[3N:6]([C:7]([H:33])([H:34])[H:35])([C:5]([H:31])([H:32])[C:4]([H:29])([H:30])[C:3]1([H:27])[H:28])[C:8]([H:36])([H:37])[C:9]([H:38])([H:39])[C:10]([H:40])([H:41])[4P:11]->2([C:12]([H:42])([H:43])[H:44])[C:13]([H:45])([H:46])[H:47])([H:21])([H:22])[H:23]\", \"dummies\": []}\nC     -3.4631     0.3317    -0.4706\nP     -2.3383    -0.6632     0.5029\nC     -2.6696    -0.4083     2.2424\nC     -2.5656    -2.3715     0.1035\nC     -1.2450    -3.1273     0.3163\nC      0.1612    -3.1440    -0.4387\nN      0.2708    -1.9458    -1.3069\nC     -0.7761    -1.9919    -2.3415\nC      1.5821    -1.9253    -1.9431\nC      1.7341    -0.6293    -2.7661\nC      2.8006     0.2757    -2.2157\nP      2.4168     0.6856    -0.5197\nC      2.6023     2.4478    -0.2756\nC      3.5350    -0.1903     0.5746\nC      0.6756    -1.0690     1.7316\nO      1.0556    -1.6703     2.7056\nC     -0.2457     1.7647     1.1853\nO     -0.3841     2.7589     1.8531\nC     -0.6771     1.0714    -1.7353\nO     -1.0571     1.6727    -2.7094\nRu     0.0000     0.0000     0.0000\nH     -4.5090     0.1426    -0.1379\nH     -3.2207     1.4026    -0.3343\nH     -3.3617     0.0632    -1.5418\nH     -3.7162    -0.7004     2.4662\nH     -2.5225     0.6627     2.4939\nH     -1.9762    -1.0279     2.8451\nH     -3.3507    -2.8047     0.7613\nH     -2.8761    -2.4643    -0.9486\nH     -1.0166    -3.0256     1.3975\nH     -1.5625    -4.1924     0.2685\nH      0.9824    -3.1360     0.3084\nH      0.2364    -4.0643    -1.0639\nH     -1.5125    -1.2086    -2.1494\nH     -1.2773    -2.9864    -2.3185\nH     -0.3173    -1.8317    -3.3395\nH      2.3664    -1.9634    -1.1696\nH      1.6820    -2.8088    -2.6183\nH      0.8420    -0.0844    -3.0502\nH      2.1152    -0.9448    -3.7630\nH      2.8450     1.2076    -2.8215\nH      3.7845    -0.2416    -2.2587\nH      2.7901     2.6546     0.7975\nH      3.4575     2.8167    -0.8784\nH      1.6741     2.9652    -0.5951\nH      3.1931    -1.2399     0.6901\nH      4.5574    -0.1797     0.1442\nH      3.5462     0.3042     1.5625\n","xyz");
# 	viewer_16763817822501125.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_16763817822501125.setBackgroundColor("white");
# 	viewer_16763817822501125.zoomTo();
# viewer_16763817822501125.render();
# });
# </script>

# %%
# remove junk
import os
os.remove(path)

# %% [markdown]
# ## Stereomers generation
#
# The main part of the MACE package is a stereomer-search functionality:

# %%
ligands = ['[NH2:1]CC[NH2:1]', '[NH2:1]CC[NH2:1]', '[F-:1]', '[F-:1]']
X = mace.ComplexFromLigands(ligands = ligands, CA = '[Ru+2]', geom = 'OH')
Xs = X.GetStereomers()
len(Xs)
# Out:
# 2

# %%
emin_idxs = {}
for idx, X in enumerate(Xs):
    X.AddConformers(numConfs = 5)
    Es = [X.mol3Dx.GetConformer(i).GetDoubleProp('E') for i in range(X.GetNumConformers())]
    emin_idxs[idx] = int(np.argmin(Es))
view_complex(Xs[0], confId = emin_idxs[0])
# Out:
# <div id="3dmolviewer_1676381783964665"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1676381783964665" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_1676381783964665 = null;
# var warn = document.getElementById("3dmolwarning_1676381783964665");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1676381783964665 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1676381783964665"),{backgroundColor:"white"});
# viewer_1676381783964665.zoomTo();
# 	viewer_1676381783964665.addModel("27\n{\"conf\": 3, \"E\": 69.91, \"rms\": -1.0, \"geom\": \"OH\", \"total_charge\": 0, \"CA_charge\": 2, \"smiles\": \"C1[CH2:1][2NH2:2]->[Ru+2:3]2(<-[5F-:4])(<-[6F-:5])(<-[1NH2:6]1)<-[3NH2:7][CH2:8][CH2:9][4NH2:10]->2\", \"smiles3D\": \"C1([H:11])([H:12])[C:1]([H:13])([H:14])[2N:2]([H:15])([H:16])->[Ru+2:3]2(<-[5F-:4])(<-[6F-:5])(<-[1N:6]1([H:17])[H:18])<-[3N:7]([H:19])([H:20])[C:8]([H:21])([H:22])[C:9]([H:23])([H:24])[4N:10]->2([H:25])[H:26]\", \"smiles3Dx\": \"C1([H:11])([H:12])[C:1]([H:13])([H:14])[2N:2]([H:15])([H:16])->[Ru+2:3]2(<-[5F-:4])(<-[6F-:5])(<-[1N:6]1([H:17])[H:18])<-[3N:7]([H:19])([H:20])[C:8]([H:21])([H:22])[C:9]([H:23])([H:24])[4N:10]->2([H:25])[H:26]\", \"dummies\": []}\nC      2.7988     0.2006    -0.2523\nC      2.1430     1.6999    -0.6389\nN      0.8102     1.7988    -0.0895\nRu     0.0000     0.0000     0.0000\nF     -0.3785     0.0676    -2.0662\nF     -1.8790     0.8647     0.3725\nN      1.7721    -0.8154    -0.3513\nN      0.3568    -0.0639     1.9486\nC      0.1163    -1.4045     2.4395\nC     -1.0336    -2.1581     1.4712\nN     -0.8101    -1.7989     0.0896\nH      3.1963     0.2263     0.7871\nH      3.6256    -0.0368    -0.9603\nH      2.0973     1.8108    -1.7459\nH      2.7819     2.5062    -0.2109\nH      0.3003     2.3360    -0.6230\nH      0.8527     2.1553     0.7492\nH      1.7804    -1.1756    -1.1898\nH      1.9321    -1.4694     0.2617\nH      1.2237     0.1660     2.1061\nH     -0.1961     0.5213     2.3785\nH     -0.2564    -1.3547     3.4882\nH      1.0648    -1.9862     2.4100\nH     -0.9492    -3.2631     1.5860\nH     -2.0517    -1.8296     1.7801\nH     -1.6062    -1.7967    -0.3568\nH     -0.2474    -2.4053    -0.2951\n","xyz");
# 	viewer_1676381783964665.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_1676381783964665.setBackgroundColor("white");
# 	viewer_1676381783964665.zoomTo();
# viewer_1676381783964665.render();
# });
# </script>

# %%
view_complex(Xs[1])
# Out:
# <div id="3dmolviewer_1676381783986146"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_1676381783986146" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_1676381783986146 = null;
# var warn = document.getElementById("3dmolwarning_1676381783986146");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1676381783986146 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1676381783986146"),{backgroundColor:"white"});
# viewer_1676381783986146.zoomTo();
# 	viewer_1676381783986146.addModel("27\n{\"conf\": 0, \"E\": 69.62, \"rms\": -1.0, \"geom\": \"OH\", \"total_charge\": 0, \"CA_charge\": 2, \"smiles\": \"C1[CH2:1][2NH2:2]->[Ru+2:3]2(<-[3F-:4])(<-[5F-:5])(<-[1NH2:6]1)<-[4NH2:7][CH2:8][CH2:9][6NH2:10]->2\", \"smiles3D\": \"C1([H:11])([H:12])[C:1]([H:13])([H:14])[2N:2]([H:15])([H:16])->[Ru+2:3]2(<-[3F-:4])(<-[5F-:5])(<-[1N:6]1([H:17])[H:18])<-[4N:7]([H:19])([H:20])[C:8]([H:21])([H:22])[C:9]([H:23])([H:24])[6N:10]->2([H:25])[H:26]\", \"smiles3Dx\": \"C1([H:11])([H:12])[C:1]([H:13])([H:14])[2N:2]([H:15])([H:16])->[Ru+2:3]2(<-[3F-:4])(<-[5F-:5])(<-[1N:6]1([H:17])[H:18])<-[4N:7]([H:19])([H:20])[C:8]([H:21])([H:22])[C:9]([H:23])([H:24])[6N:10]->2([H:25])[H:26]\", \"dummies\": []}\nC      2.0293     1.2985    -1.4480\nC      0.8287     2.4326    -1.1387\nN      0.0063     1.9765    -0.0414\nRu     0.0000     0.0000     0.0000\nF      1.3904     0.0286     1.5775\nF     -1.3904    -0.0286    -1.5775\nN      1.4832    -0.0319    -1.3067\nN     -0.0063    -1.9765     0.0414\nC     -0.8287    -2.4326     1.1387\nC     -2.0293    -1.2985     1.4480\nN     -1.4832     0.0319     1.3067\nH      2.8646     1.4357    -0.7245\nH      2.4107     1.4351    -2.4859\nH      1.2982     3.4069    -0.8710\nH      0.1975     2.5619    -2.0469\nH     -0.8465     2.2811    -0.1534\nH      0.3429     2.2962     0.7444\nH      1.1709    -0.3200    -2.1144\nH      2.1351    -0.5987    -1.0130\nH      0.8465    -2.2811     0.1534\nH     -0.3429    -2.2962    -0.7444\nH     -0.1975    -2.5619     2.0469\nH     -1.2982    -3.4069     0.8710\nH     -2.8646    -1.4357     0.7245\nH     -2.4107    -1.4351     2.4859\nH     -1.1709     0.3200     2.1144\nH     -2.1351     0.5987     1.0130\n","xyz");
# 	viewer_1676381783986146.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_1676381783986146.setBackgroundColor("white");
# 	viewer_1676381783986146.zoomTo();
# viewer_1676381783986146.render();
# });
# </script>

# %% [markdown]
# Further in this section we will review the main parameters of stereomer search and some important usage scenarios

# %% [markdown]
# ### Stereochemistry control
#
# There are three regimes stereomer search (`regime` parameter):
#
# * "CA": changes stereochemistry of the central atom only, ignores undefined stereocenters in ligands;
#
# * "ligands": changes stereochemistry of undefined stereocenters in ligands only, ignores central atom;
#
# * "all": default choice, changes stereochemistry of all undefined stereocenters.

# %% [markdown]
# `ligands` regime can be useful if one want to fix stereochemistry of the central atom. This could be the case for ligands containing aliphatic amine donor group with three different substituents, which will form a chiral center after binding to the metal:

# %%
ligands = ['C[N:1](C)CC[N:2](C)CC[P:3](C)C', '[C-:4]#[O+]', '[H-:5]', '[H-:6]']
X = mace.ComplexFromLigands(ligands = ligands, CA = '[Ru+2]', geom = 'OH')
Xs = X.GetStereomers(regime = 'ligands')
len(Xs)
# Out:
# 1

# %%
emin_idxs = {}
for idx, X in enumerate(Xs):
    X.AddConformers(numConfs = 3)
    Es = [X.mol3Dx.GetConformer(i).GetDoubleProp('E') for i in range(X.GetNumConformers())]
    emin_idxs[idx] = int(np.argmin(Es))
view_complex(Xs[0], confId = emin_idxs[0])
# Out:
# <div id="3dmolviewer_16763817846677687"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16763817846677687" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_16763817846677687 = null;
# var warn = document.getElementById("3dmolwarning_16763817846677687");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16763817846677687 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16763817846677687"),{backgroundColor:"white"});
# viewer_16763817846677687.zoomTo();
# 	viewer_16763817846677687.addModel("40\n{\"conf\": 2, \"E\": 448.14, \"rms\": -1.0, \"geom\": \"OH\", \"total_charge\": 0, \"CA_charge\": 2, \"smiles\": \"C[1N:1]1([CH3:2])->[Ru+2:3]2(<-[4C-:4]#[O+:5])(<-[5H-:6])(<-[6H-:7])<-[2N:8]([CH3:9])([CH2:10][CH2:11]1)[CH2:12][CH2:13][3P:14]->2([CH3:15])[CH3:16]\", \"smiles3D\": \"C([1N:1]1([C:2]([H:20])([H:21])[H:22])->[Ru+2:3]2(<-[4C-:4]#[O+:5])(<-[5H-:6])(<-[6H-:7])<-[2N:8]([C:9]([H:23])([H:24])[H:25])([C:10]([H:26])([H:27])[C:11]1([H:28])[H:29])[C:12]([H:30])([H:31])[C:13]([H:32])([H:33])[3P:14]->2([C:15]([H:34])([H:35])[H:36])[C:16]([H:37])([H:38])[H:39])([H:17])([H:18])[H:19]\", \"smiles3Dx\": \"C([1N:1]1([C:2]([H:20])([H:21])[H:22])->[Ru+2:3]2(<-[4C-:4]#[O+:5])(<-[5H-:6])(<-[6H-:7])<-[2N:8]([C:9]([H:23])([H:24])[H:25])([C:10]([H:26])([H:27])[C:11]1([H:28])[H:29])[C:12]([H:30])([H:31])[C:13]([H:32])([H:33])[3P:14]->2([C:15]([H:34])([H:35])[H:36])[C:16]([H:37])([H:38])[H:39])([H:17])([H:18])[H:19]\", \"dummies\": []}\nC     -1.1282     1.7637    -2.0810\nN     -1.5743     0.6413    -1.3165\nC     -2.7109     1.0124    -0.5504\nRu     0.0000     0.0000     0.0000\nC     -0.5623     1.5249     1.4157\nO     -0.8769     2.3780     2.2077\nH      1.0632     1.0829    -0.7446\nH      1.2380    -0.5038     1.0343\nN      0.5331    -1.4481    -1.3439\nC      1.8429    -1.2439    -1.7479\nC     -0.4488    -1.3762    -2.6343\nC     -1.9272    -0.4431    -2.2115\nC      0.3816    -3.1509    -0.5300\nC     -1.2154    -3.1824     0.6452\nP     -1.5915    -1.6233     1.1154\nC     -3.2612    -1.2449     0.6326\nC     -1.4382    -1.4830     2.8925\nH     -0.7810     2.5669    -1.3930\nH     -1.9711     2.1473    -2.7061\nH     -0.2890     1.4527    -2.7410\nH     -3.6013     0.4987    -0.9426\nH     -2.5709     0.7550     0.3912\nH     -2.8596     2.1182    -0.6161\nH      2.1547    -2.0687    -2.4250\nH      1.9177    -0.2753    -2.2857\nH      2.5054    -1.2252    -0.8587\nH     -0.7348    -2.4039    -2.9392\nH      0.0790    -0.8737    -3.4742\nH     -2.5797    -1.0421    -1.7643\nH     -2.3820    -0.0254    -3.1410\nH      1.2898    -3.3539     0.0746\nH      0.2786    -3.9281    -1.3149\nH     -1.0018    -3.7982     1.5430\nH     -2.0725    -3.6190     0.0926\nH     -3.9042    -2.1336     0.7977\nH     -3.6381    -0.3988     1.2393\nH     -3.2763    -1.0424    -0.1529\nH     -2.0492    -2.2706     3.3798\nH     -1.7955    -0.4843     3.2167\nH     -0.3747    -1.6074     3.1829\n","xyz");
# 	viewer_16763817846677687.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_16763817846677687.setBackgroundColor("white");
# 	viewer_16763817846677687.zoomTo();
# viewer_16763817846677687.render();
# });
# </script>

# %%
view_complex(Xs[1], confId = emin_idxs[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 view_complex(Xs[1], confId = emin_idxs[1])
#
# IndexError: list index out of range

# %% [markdown]
# Using this regime, one should remember that some of conformers are diastereomers.

# %% [markdown]
# There are almost no problems where the `CA` regime will be preferable. Indeed, if original ligands has undefined stereocenters, conformers of identified stereomers will not be true conformers in general case, but diastereomers. Therefore, it should be used carefully.
#
# On the contrary, the `all` regime can be used in almost any situation.

# %% [markdown]
# The other parameter controlling stereomers search is `dropEnantiomers`. If `True`, it reduces pairs of enantiomers to one complex:

# %%
ligands = ['[NH2:1]CC[NH2:1]', '[NH2:1]CC[NH2:1]', '[NH2:1]CC[NH2:1]']
X = mace.ComplexFromLigands(ligands, '[Ru+2]', 'OH')
len(X.GetStereomers(dropEnantiomers = True))
# Out:
# 1

# %%
len(X.GetStereomers(dropEnantiomers = False))
# Out:
# 2

# %% [markdown]
# Consideration of both enantiomers may be necessary only if the complex is in a chiral environment that is not its ligand, which is quite rare for homogeneous catalysis.

# %% [markdown]
# ### Rule-based filtering
#
# Unlike monodentate ligands, relative positions of donor atoms in complexes of chelates and multidentate ligands are restricted by the ligand's structure. The most obvious scenario is coordination of bidentate ligand: unless the ligand is "long", donor atoms can not be in *trans-* position to each other. In MACE, this idea is controlled by the `minTransCycle` parameter, which is the minimal size of the ..DA->M<-DA.. cycle, where DA are in trans- position to each other and belong to one ligand:

# %%
X = mace.ComplexFromLigands(['[NH2:1]CCCCCCCCCCCCC[NH2:1]', '[Cl-:1]', '[Cl-:1]'], '[Pt+2]', 'SP')
len(X.GetStereomers(minTransCycle = None)) # default, those DAs can not be in trans-position never
# Out:
# 1

# %%
Xs = X.GetStereomers(minTransCycle = 12)
len(Xs)
# Out:
# 2

# %%
for X in Xs:
    X.AddConformer()
view_complex(Xs[0])
# Out:
# <div id="3dmolviewer_16763818402715917"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16763818402715917" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_16763818402715917 = null;
# var warn = document.getElementById("3dmolwarning_16763818402715917");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16763818402715917 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16763818402715917"),{backgroundColor:"white"});
# viewer_16763818402715917.zoomTo();
# 	viewer_16763818402715917.addModel("48\n{\"conf\": 0, \"E\": 90.36, \"rms\": -1.0, \"geom\": \"SP\", \"total_charge\": 0, \"CA_charge\": 2, \"smiles\": \"C1[CH2:1][CH2:2][CH2:3][CH2:4][CH2:5][CH2:6][1NH2:7]->[Pt+2:8](<-[3Cl-:9])(<-[4Cl-:10])<-[2NH2:11][CH2:12][CH2:13][CH2:14][CH2:15][CH2:16][CH2:17]1\", \"smiles3D\": \"C1([H:18])([H:19])[C:1]([H:20])([H:21])[C:2]([H:22])([H:23])[C:3]([H:24])([H:25])[C:4]([H:26])([H:27])[C:5]([H:28])([H:29])[C:6]([H:30])([H:31])[1N:7]([H:32])([H:33])->[Pt+2:8](<-[3Cl-:9])(<-[4Cl-:10])<-[2N:11]([H:34])([H:35])[C:12]([H:36])([H:37])[C:13]([H:38])([H:39])[C:14]([H:40])([H:41])[C:15]([H:42])([H:43])[C:16]([H:44])([H:45])[C:17]1([H:46])[H:47]\", \"smiles3Dx\": \"C1([H:18])([H:19])[C:1]([H:20])([H:21])[C:2]([H:22])([H:23])[C:3]([H:24])([H:25])[C:4]([H:26])([H:27])[C:5]([H:28])([H:29])[C:6]([H:30])([H:31])[1N:7]([H:32])([H:33])->[Pt+2:8](<-[3Cl-:9])(<-[4Cl-:10])(<-[*:48])(<-[*:49])<-[2N:11]([H:34])([H:35])[C:12]([H:36])([H:37])[C:13]([H:38])([H:39])[C:14]([H:40])([H:41])[C:15]([H:42])([H:43])[C:16]([H:44])([H:45])[C:17]1([H:46])[H:47]\", \"dummies\": [-1.7056541638429046, 0.7117666060655443, 0.282552592558706, 1.699523489583247, -0.7092194091952568, -0.2815416885478236]}\nC     -1.3121    -6.6205    -1.4721\nC     -1.5085    -6.7133    -2.9960\nC     -1.2324    -5.4001    -3.7567\nC      0.2430    -4.9453    -3.6774\nC      0.4518    -3.7282    -2.7557\nC      0.1012    -2.4030    -3.4573\nC      0.4188    -1.1760    -2.5674\nN     -0.6682    -0.9155    -1.7276\nPt     0.0000     0.0000     0.0000\nCl     0.7552     1.0344     1.9521\nCl     0.5912     1.9089    -1.2401\nN     -0.5120    -1.6535     1.0742\nC     -1.7169    -1.4308     1.7176\nC     -2.2594    -2.7623     2.2659\nC     -3.2204    -3.4342     1.2658\nC     -3.3030    -4.9571     1.4602\nC     -2.1774    -5.7157     0.7313\nC     -2.4227    -5.8145    -0.7847\nH     -0.3188    -6.1857    -1.2377\nH     -1.3211    -7.6533    -1.0611\nH     -2.5475    -7.0422    -3.2104\nH     -0.8360    -7.5043    -3.3947\nH     -1.9253    -4.6016    -3.4208\nH     -1.4792    -5.5839    -4.8252\nH      0.8872    -5.7785    -3.3187\nH      0.6115    -4.7037    -4.6995\nH      1.5272    -3.7021    -2.4647\nH     -0.1428    -3.8409    -1.8230\nH      0.7073    -2.3193    -4.3859\nH     -0.9699    -2.3833    -3.7507\nH      0.6096    -0.2910    -3.2113\nH      1.3223    -1.3884    -1.9505\nH     -1.0812    -1.6958    -1.5164\nH     -1.2609    -0.3624    -2.1573\nH     -0.5963    -2.3807     0.5021\nH      0.1368    -1.8271     1.6940\nH     -1.5596    -0.7067     2.5729\nH     -2.4476    -1.0010     0.9977\nH     -2.8063    -2.5786     3.2163\nH     -1.4023    -3.4259     2.5016\nH     -4.2315    -3.0008     1.4126\nH     -2.9278    -3.1977     0.2228\nH     -3.2574    -5.1921     2.5465\nH     -4.2860    -5.3219     1.0951\nH     -1.2006    -5.2238     0.9220\nH     -2.1233    -6.7438     1.1507\nH     -2.4595    -4.7988    -1.2236\nH     -3.4009    -6.3102    -0.9686\n","xyz");
# 	viewer_16763818402715917.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_16763818402715917.setBackgroundColor("white");
# 	viewer_16763818402715917.zoomTo();
# viewer_16763818402715917.render();
# });
# </script>

# %%
view_complex(Xs[1])
# Out:
# <div id="3dmolviewer_16763818412499812"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16763818412499812" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_16763818412499812 = null;
# var warn = document.getElementById("3dmolwarning_16763818412499812");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16763818412499812 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16763818412499812"),{backgroundColor:"white"});
# viewer_16763818412499812.zoomTo();
# 	viewer_16763818412499812.addModel("48\n{\"conf\": 0, \"E\": 90.68, \"rms\": -1.0, \"geom\": \"SP\", \"total_charge\": 0, \"CA_charge\": 2, \"smiles\": \"C1[CH2:1][CH2:2][CH2:3][CH2:4][CH2:5][CH2:6][1NH2:7]->[Pt+2:8](<-[2Cl-:9])(<-[4Cl-:10])<-[3NH2:11][CH2:12][CH2:13][CH2:14][CH2:15][CH2:16][CH2:17]1\", \"smiles3D\": \"C1([H:18])([H:19])[C:1]([H:20])([H:21])[C:2]([H:22])([H:23])[C:3]([H:24])([H:25])[C:4]([H:26])([H:27])[C:5]([H:28])([H:29])[C:6]([H:30])([H:31])[1N:7]([H:32])([H:33])->[Pt+2:8](<-[2Cl-:9])(<-[4Cl-:10])<-[3N:11]([H:34])([H:35])[C:12]([H:36])([H:37])[C:13]([H:38])([H:39])[C:14]([H:40])([H:41])[C:15]([H:42])([H:43])[C:16]([H:44])([H:45])[C:17]1([H:46])[H:47]\", \"smiles3Dx\": \"C1([H:18])([H:19])[C:1]([H:20])([H:21])[C:2]([H:22])([H:23])[C:3]([H:24])([H:25])[C:4]([H:26])([H:27])[C:5]([H:28])([H:29])[C:6]([H:30])([H:31])[1N:7]([H:32])([H:33])->[Pt+2:8](<-[2Cl-:9])(<-[4Cl-:10])(<-[*:48])(<-[*:49])<-[3N:11]([H:34])([H:35])[C:12]([H:36])([H:37])[C:13]([H:38])([H:39])[C:14]([H:40])([H:41])[C:15]([H:42])([H:43])[C:16]([H:44])([H:45])[C:17]1([H:46])[H:47]\", \"dummies\": [1.5036343545595376, -1.092084475838556, 0.13581653885821293, -1.5036343824810376, 1.0920844952715243, -0.13581654065952783]}\nC     -4.3177     4.8832    -0.9320\nC     -5.3385     4.0723    -0.1008\nC     -5.0931     2.5528    -0.1590\nC     -3.9641     2.1230     0.7888\nC     -3.7784     0.5970     0.8332\nC     -2.7685     0.1028    -0.2145\nC     -2.4691    -1.3932    -0.0593\nN     -1.1543    -1.6426    -0.4284\nPt     0.0000     0.0000     0.0000\nCl     0.4265     0.3008    -2.3028\nCl    -0.4261    -0.3006     2.3008\nN      1.1585     1.6486     0.4299\nC      0.7564     2.7267    -0.3764\nC      0.9799     4.0598     0.3916\nC     -0.2840     4.5437     1.1269\nC     -1.2767     5.2119     0.1601\nC     -2.5940     5.5884     0.8580\nC     -3.6726     6.0429    -0.1440\nH     -4.8536     5.3244    -1.8010\nH     -3.5402     4.2265    -1.3708\nH     -6.3549     4.2716    -0.5062\nH     -5.3635     4.4068     0.9596\nH     -4.8666     2.2360    -1.2004\nH     -6.0309     2.0416     0.1510\nH     -4.2161     2.4693     1.8155\nH     -3.0121     2.6136     0.4955\nH     -4.7505     0.0733     0.7014\nH     -3.3970     0.3353     1.8446\nH     -3.1487     0.3043    -1.2391\nH     -1.8123     0.6522    -0.0919\nH     -3.1573    -1.9805    -0.7140\nH     -2.6204    -1.6945     1.0045\nH     -0.8397    -2.3652     0.0347\nH     -1.1172    -1.8156    -1.3249\nH      2.0367     1.4554     0.2647\nH      1.0562     1.8713     1.3088\nH      1.3579     2.7334    -1.3152\nH     -0.3188     2.6202    -0.6270\nH      1.8132     3.9410     1.1169\nH      1.3064     4.8430    -0.3274\nH      0.0131     5.2857     1.8997\nH     -0.7658     3.6861     1.6463\nH     -1.4782     4.5292    -0.6859\nH     -0.8155     6.1328    -0.2597\nH     -2.3889     6.4270     1.5586\nH     -2.9741     4.7447     1.4687\nH     -3.2202     6.7609    -0.8628\nH     -4.4662     6.5983     0.4021\n","xyz");
# 	viewer_16763818412499812.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_16763818412499812.setBackgroundColor("white");
# 	viewer_16763818412499812.zoomTo();
# viewer_16763818412499812.render();
# });
# </script>

# %% [markdown]
# `merRule` is another similar parameter. It restricts "rigid" DA-DA-DA fragments (e.g. terpyridine) to be in meridial conformation:

# %%
ligands = ['[n:1]1ccccc1-c([n:1]1)cccc1-c1cccc[n:1]1', '[Cl-:1]', '[Cl-:1]', '[Cl-:1]']
X = mace.ComplexFromLigands(ligands, '[Fe+3]', 'OH')
X.mol

# %%
len(X.GetStereomers(merRule = True))
# Out:
# 1

# %%
len(X.GetStereomers(merRule = False))
# Out:
# 2

# %% [markdown]
# In most cases merRule nicely filters "impossible" stereomers, though experience shows that in some cases it throws out energetically possible structures due to simplicity of the "rigidity"-determining algorithm. Thus this parameter should be treated carefully, especially for new systems.

# %% [markdown]
# ### Issue of resonance structures
#
# The main part of MACE implementation of stereomers generation algorithm is a pairwise comparison of isomers which is based on molecular graphs. Some symmetrical conjugated systems have non-symmetrical molecular graph, e.g. dithiocarboxylates. Indeed, in both sulfur atoms in `CC(=S)[S-]` are identical, even though in molecular graph one atom forms a single bond and the other forms a double bond. When such ligands will act as bidentate ligands, there are possibility that the final set of isomers will contain identical systems:

# %%
smiles = '[Pd+2](<-[S-:1]1)(<-[S:2]=C1C)(<-[S-:3]1)(<-[S:4]=C1C)'
X1 = mace.Complex(smiles, 'SP', maxResonanceStructures = 1)
X1_isomers = X1.GetStereomers()
len(X1_isomers)
# Out:
# 2

# %%
X1_isomers[0].mol

# %%
X1_isomers[1].mol

# %% [markdown]
# In MACE this problem is solved for carboxylates and NCN-carbenes, but for other systems one should use `maxResonanceStructures` parameter during `Complex` initialization. It is a number of resonance structures which will be considered for the complex during generation of a data structure for isomers' comparison. The larger its value, the higher the probability of filtering duplicated stereomers:

# %%
X2 = mace.Complex(smiles, 'SP', maxResonanceStructures = 4)
X2_isomers = X2.GetStereomers()
len(X2_isomers)
# Out:
# 1

# %% [markdown]
# However, such approach can be extremely time consuming for large conjugated systems.

# %% [markdown]
# ## Special features

# %% [markdown]
# ### Adding substituents
#
# One of the most popular problems in computational chemistry is the search for the most efficient system by introducing various substituents to the core structure. To make such tasks easier, MACE contains functionality for introducing substituents to both ligands and complexes. To use it, one need to start with getting ChemAxon SMILES of the ligand with R/R1/R2/etc substituents:

# %%
ligand = 'C[P:3](C)CC1=CC([*])=C([*])C(C[P:1](C)C)=[N:2]1 |$;;;;;;;_R1;;_R2;;;;;;$,c:14,t:4,7|'
L = mace.MolFromSmiles(ligand)
L

# %% [markdown]
# or to use specify substituents as dummy atoms in RDKit SMILES format. To add substituents to the ligand one need to use `mace.AddSubsToMol` function:

# %%
subs = {'R1': mace.MolFromSmiles('[*]OC'),
        'R2': mace.MolFromSmiles('[*]C#N')}
ligand_sub = mace.AddSubsToMol(L, subs)
ligand_sub

# %% [markdown]
# For the complex, the same procedure is a little trickier:

# %%
core = mace.ComplexFromLigands([ligand, '[Cl-:4]'], '[Rh+]', 'SP')
core.mol

# %%
X = mace.ComplexFromMol(mace.AddSubsToMol(core.mol, subs), core._geom)
X.mol

# %% [markdown]
# ### Constrained embedding
#
# When analyzing conformations of complexes with one core and different substituents, constrained embedding can be a nice solution. The idea is to fix the geometry of the core and optimize coordinates of other atoms. In MACE this is implemented in the `AddConstrainedConformer` / `AddConstrainedConformers` methods. Compared to the `AddConstrainedConformer` / `AddConstrainedConformers` methods, they take additional parameter `core` which must be (1) a `Complex` object, (2) substructure of the current `Complex`, and (3) must have at least one generated conformer:

# %%
core.AddConformer()
view_complex(core)
# Out:
# <div id="3dmolviewer_16763818845752566"  style="position: relative; width: 640px; height: 480px">
#         <p id="3dmolwarning_16763818845752566" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.1/3Dmol-min.js');
# }
#
# var viewer_16763818845752566 = null;
# var warn = document.getElementById("3dmolwarning_16763818845752566");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_16763818845752566 = $3Dmol.createViewer(document.getElementById("3dmolviewer_16763818845752566"),{backgroundColor:"white"});
# viewer_16763818845752566.zoomTo();
# 	viewer_16763818845752566.addModel("35\n{\"conf\": 0, \"E\": 9587.03, \"rms\": -1.0, \"geom\": \"SP\", \"total_charge\": 0, \"CA_charge\": 1, \"smiles\": \"C[3P:1]1([CH3:2])->[Rh+:17]2(<-[4Cl-:16])<-[1P:12]([CH3:13])([CH3:14])[CH2:11][c:10]3[c:8]([2*:9])[c:6]([1*:7])[cH:5][c:4]([2n:15]->23)[CH2:3]1\", \"smiles3D\": \"C([3P:1]1([C:2]([H:21])([H:22])[H:23])->[Rh+:17]2(<-[4Cl-:16])<-[1P:12]([C:13]([H:29])([H:30])[H:31])([C:14]([H:32])([H:33])[H:34])[C:11]([H:27])([H:28])[c:10]3[c:8]([2*:9])[c:6]([1*:7])[c:5]([H:26])[c:4]([2n:15]->23)[C:3]1([H:24])[H:25])([H:18])([H:19])[H:20]\", \"smiles3Dx\": \"C([3P:1]1([C:2]([H:21])([H:22])[H:23])->[Rh+:17]2(<-[4Cl-:16])(<-[*:35])(<-[*:36])<-[1P:12]([C:13]([H:29])([H:30])[H:31])([C:14]([H:32])([H:33])[H:34])[C:11]([H:27])([H:28])[c:10]3[c:8]([2*:9])[c:6]([1*:7])[c:5]([H:26])[c:4]([2n:15]->23)[C:3]1([H:24])[H:25])([H:18])([H:19])[H:20]\", \"dummies\": [1.1104958181948377, 1.0946407146240706, 1.0561566774757922, -1.1105059022419412, -1.0946521870690464, -1.056167731020658]}\nC      0.0784     0.4154    -3.1835\nP      1.1115     0.5461    -1.7293\nC      1.7168     2.2209    -1.5604\nC      2.4922    -0.5925    -1.8566\nC      2.3583    -1.6936    -0.5706\nC      3.4714    -2.4266    -0.1617\nC      3.3679    -3.1393     1.0661\nX      3.6567    -3.6778     1.7405\nC      2.1978    -3.1015     1.8773\nX      3.0112    -3.5058     1.9328\nC      1.1211    -2.3485     1.4089\nC     -0.1896    -2.0120     2.4344\nP     -1.0590    -0.6024     1.7433\nC     -1.0899     0.7357     2.9300\nC     -2.7298    -1.0706     1.3094\nN      1.2681    -1.5550     0.2783\nCl    -1.5106     1.8524    -0.3315\nRh     0.0000     0.0000     0.0000\nH      0.7095     0.4882    -4.0932\nH     -0.4484    -0.5605    -3.1762\nH     -0.6661     1.2375    -3.1832\nH      0.9012     2.9345    -1.7969\nH      2.5625     2.3807    -2.2603\nH      2.0622     2.3860    -0.5193\nH      3.4492    -0.0359    -1.7792\nH      2.4471    -1.1342    -2.8238\nH      4.3820    -2.4474    -0.7452\nH      0.1800    -1.7663     3.4516\nH     -0.8679    -2.8887     2.4803\nH     -1.3257     0.3323     3.9362\nH     -1.8649     1.4726     2.6362\nH     -0.0980     1.2318     2.9537\nH     -3.2062    -1.5817     2.1711\nH     -2.7070    -1.7574     0.4384\nH     -3.3122    -0.1634     1.0496\n","xyz");
# 	viewer_16763818845752566.setStyle({"stick": {"radius": 0.15}, "sphere": {"scale": 0.3}});
# 	viewer_16763818845752566.setBackgroundColor("white");
# 	viewer_16763818845752566.zoomTo();
# viewer_16763818845752566.render();
# });
# </script>

# %%
X.AddConstrainedConformer(core, confId = core.GetMinEnergyConfId(0))
view_complex(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 X.AddConstrainedConformer(core, confId = core.GetMinEnergyConfId(0))
# ----> 2 view_complex(X)
#
# Cell In[4], line 6, in view_complex(X, confId)
#       4 '''Shows molecule corresponding to the SMILES'''
#       5 view = py3Dmol.view()
# ----> 6 view.addModel(X.ToXYZBlock(confId = confId), 'xyz')
#       7 view.setStyle({'stick': {'radius': 0.15}, 'sphere': {'scale': 0.3}})
#       8 view.setBackgroundColor('white')
#
# File C:\Programming\Anaconda3\envs\test1\lib\site-packages\mace\complex_object.py:1114, in Complex.ToXYZBlock(self, confId)
#    1112 N = self.mol3D.GetNumConformers()
#    1113 if not N:
# -> 1114     raise ValueError('Bad conformer ID: complex has no conformers')
#    1115 # prepare conf idxs
#    1116 if confId in (-2, 'all'):
#
# ValueError: Bad conformer ID: complex has no conformers

# %% [markdown]
# Currently MACE supports monovalent substituents only.

# %% [markdown]
# ### Prepare ligands for MolSimplify
#
# Like MACE, [MolSimplify](https://github.com/hjkgrp/molSimplify) is a package for the automated screening and discovery of new inorganic molecules. It uses OpenBabel as 3D embedding engine, and fails generating conformers of complex multidentate ligands from SMILES. However, it works perfectly fine if the ligand already have pregenerated geometry which in most cases has to be prepared manually.
#
# Lucky for us, MACE can be used to automatically generate conformations of coordinated ligands with a structure of almost any complexity. For the purpose, one must generate 3D coordinated for any complex containing desired ligand, and cut it from the complex using the `GetBondedLigand` method (`num` parameter is an isotopic number of the ligand's donor atom):

# %%
ligands = ['[n:1]1ccccc1-c([n:2]1)cccc1CNCC[P:6](C)C', '[C-:3]#[O+]', '[C-:4]#[O+]', '[C-:5]#[O+]']
num = 1
X = mace.ComplexFromLigands(ligands, '[Ru+2]', 'OH')
Xs = X.AddConformers(numConfs = 10)
idx_min = X.GetMinEnergyConfId(0)
view_complex(X, idx_min)

# %%
mol = X.GetBondedLigand(num)

from rdkit import Chem

def view_mol(mol, confId = 0):
    '''Shows molecule corresponding to the SMILES'''
    view = py3Dmol.view()
    view.addModel(Chem.MolToMolBlock(mol, confId = confId), 'mol')
    view.setStyle({'stick': {'radius': 0.15}, 'sphere': {'scale': 0.3}})
    view.setBackgroundColor('white')
    view.zoomTo()
    
    return view

view_mol(mol, idx_min)

# %% [markdown]
# Obtained conformer can be save in `mol` / `xyz` format and stored in the molSimplify library of ligands.
